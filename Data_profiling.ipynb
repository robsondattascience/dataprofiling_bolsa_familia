# %% [markdown]
# <a href="https://colab.research.google.com/github/robsondattascience/dataprofiling_bolsa_familia/blob/main/Data_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalando a biblioteca pandas
# %pip install pandas

# %%
#Instalando a biblioteca pandas-profiling
# %pip install pandas-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.3/357.3 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 14.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 26.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 33.4 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=6f8a1bc692558c6c8c0912443e0e738c1e60189b5d37bf45f63832a79b7f18f8
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.2.1
# ...

# %%
#Imports das bibliotecas
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# <ipython-input-3-935884e824b8>:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
#Colocando base do CSV em um DF, coloque abaixo o caminho da sua máquina
df = pd.read_csv('/content/base.csv',';')
# Out:
# <ipython-input-4-4a4c45a24435>:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df = pd.read_csv('/content/base.csv',';')

# %%
#Gerando o profile
profile = ProfileReport(df, title="Profiling base bolsa familia",html={'style':{'full_width':True}})

# %%
#Exportando o profiling
profile.to_file("profiling_base_bolsa_familia.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
